# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ### WAP to sum of numbers

# %%
def sum_num(a,b):

    sum = a + b 

    return sum

sum_num(2,3)
# Out:
# 5

# %% [markdown]
# ### Numpy Introduction
#
# 1. Extensible Library
# 2. Faster than core python
# 3. Numeric - python
# 4. Mathematical Operations like arithmetic algebra random sampling
# 5. Multi - dimensional Array, Matrix, String

# %% [markdown]
# ### Array Introduction
# 1. array([])
# 2. Homogeneous
# 3. Ordered
# 4. Mutable,  Size- Immutable
# 5. Duplicate elements are allowed
# 6. numpy array is 50x faster than core python list
